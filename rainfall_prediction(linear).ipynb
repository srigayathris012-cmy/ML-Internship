# %%
#import libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression # Import LogisticRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/ML project files/Rainfall.csv')  #load dataset
print(data)
# Out:
#      day  pressure   maxtemp  temparature  mintemp  dewpoint  humidity   \
# 0      1     1025.9     19.9         18.3     16.8      13.1         72
# 1      2     1022.0     21.7         18.9     17.2      15.6         81
# 2      3     1019.7     20.3         19.3     18.0      18.4         95
# 3      4     1018.9     22.3         20.6     19.1      18.8         90
# 4      5     1015.9     21.3         20.7     20.2      19.9         95
# ..   ...        ...      ...          ...      ...       ...        ...
# 361   27     1022.7     18.8         17.7     16.9      15.0         84
# 362   28     1026.6     18.6         17.3     16.3      12.8         75
# 363   29     1025.9     18.9         17.7     16.4      13.3         75
# 364   30     1025.3     19.2         17.3     15.2      13.3         78
# 365   31     1026.4     20.5         17.8     15.5      13.0         74
#
#      cloud  rainfall  sunshine           winddirection  windspeed
# 0        49      yes       9.3                    80.0       26.3
# 1        83      yes       0.6                    50.0       15.3
# 2        91      yes       0.0                    40.0       14.2
# 3        88      yes       1.0                    50.0       16.9
# 4        81      yes       0.0                    40.0       13.7
# ..      ...      ...       ...                     ...        ...
# 361      90      yes       0.0                    30.0       18.4
# 362      85      yes       1.0                    20.0       25.9
# 363      78      yes       4.6                    70.0       33.4
# 364      86      yes       1.2                    20.0       20.9
# 365      66       no       5.7                    20.0       23.3
#
# [366 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# day                       0
# pressure                  0
# maxtemp                   0
# temparature               0
# mintemp                   0
# dewpoint                  0
# humidity                  0
# cloud                     0
# rainfall                  0
# sunshine                  0
#          winddirection    1
# windspeed                 1
# dtype: int64

# %%
# Now select the columns after cleaning
rain_data = data[['temparature', 'windspeed','rainfall']].copy()
print(rain_data)
# Out:
#      temparature  windspeed rainfall
# 0           18.3       26.3      yes
# 1           18.9       15.3      yes
# 2           19.3       14.2      yes
# 3           20.6       16.9      yes
# 4           20.7       13.7      yes
# ..           ...        ...      ...
# 361         17.7       18.4      yes
# 362         17.3       25.9      yes
# 363         17.7       33.4      yes
# 364         17.3       20.9      yes
# 365         17.8       23.3       no
#
# [366 rows x 3 columns]

# %%
# Drop rows with any missing values from the relevant columns before splitting
rain_data_cleaned = rain_data.dropna(subset=['temparature', 'windspeed', 'rainfall'])
X = rain_data_cleaned[['temparature','windspeed']]
y = rain_data_cleaned['rainfall']
print(X)
# Out:
#      temparature  windspeed
# 0           18.3       26.3
# 1           18.9       15.3
# 2           19.3       14.2
# 3           20.6       16.9
# 4           20.7       13.7
# ..           ...        ...
# 361         17.7       18.4
# 362         17.3       25.9
# 363         17.7       33.4
# 364         17.3       20.9
# 365         17.8       23.3
#
# [365 rows x 2 columns]

# %%
#  Split into train and test (80% train, 20% test)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder # Import LabelEncoder

# Initialize and fit label_encoder on the full target variable 'y'
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y) # Encode 'y' before splitting

# Split X and the now-encoded y into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# The following lines are no longer needed as y_train and y_test are already encoded
# y_train = label_encoder.transform(y_train)
# y_test = label_encoder.transform(y_test)

# %%
from sklearn.preprocessing import LabelEncoder
#Encode the dependent variable (Rainfall: Yes/No -> 1/0)
label_encoder = LabelEncoder()
rain_data['rainfall'] = label_encoder.fit_transform(rain_data['rainfall'])  # Yes=1, No=0
print(rain_data)
# Out:
#      temparature  windspeed  rainfall
# 0           18.3       26.3         1
# 1           18.9       15.3         1
# 2           19.3       14.2         1
# 3           20.6       16.9         1
# 4           20.7       13.7         1
# ..           ...        ...       ...
# 361         17.7       18.4         1
# 362         17.3       25.9         1
# 363         17.7       33.4         1
# 364         17.3       20.9         1
# 365         17.8       23.3         0
#
# [366 rows x 3 columns]

# %%
# Standardize features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Model fitting
model = LogisticRegression(solver='liblinear', random_state=42) # Use LogisticRegression
model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42, solver='liblinear')

# %%
# Predict on test data
y_pred = model.predict(X_test)
y_pred_label = label_encoder.inverse_transform(y_pred)

# %%
#  Example: Predict for new data
# Input: WindSpeed, Temperature
new_data = [[5, 50]]  # Example values
new_data_scaled = scaler.transform(new_data)
new_pred = model.predict(new_data_scaled)
new_pred_label = label_encoder.inverse_transform(new_pred)
new_final_output = 'Rainfall' if new_pred_label[0]=='Yes' else 'No'

print("Prediction for new data:", new_final_output)
# Out:
# Prediction for new data: No
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
